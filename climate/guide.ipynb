# %% [markdown]
# # APEX STATS Dataset
# Prepared by Michelle Baca Reinke

# %% [markdown]
# ## Source Attribution
#
# Author: Data Copyright &copy; Angulo et al. (2023), All Rights Reserved
#
# Title: Climate Change Hope Scale
#
# Source: [Digital Scholarship @ UNLV](https://digitalscholarship.unlv.edu/psychology_fac_presentations/1/)
#
# License: IN COPYRIGHT. For more information about this rights statement, please visit [Rights Statement](http://rightsstatements.org/vocab/InC/1.0/)
#
# Changes: Data have been adapted for APEX STATS by Michelle Baca Reinke; data have been condensed in the example version.

# %% [markdown]
# ## Description of the Original Data
#
#
# The Climate Change Hope Scale (CCHS; Li & Monroe, 2017) adapted Synder et al.'s (1991) Hope Scale to focus specifically on climate change. This scale was designed to measure willpower and waypower. Willpower is the extent to which one believes that they are able to meet their goals. Waypower is the extent to which one can think of ways to overcome a problem.
#
# <br>
#
# In an adolescent sample, the CCHS consists of 11 items that can be grouped into three factors: Personal-sphere willpower and waypower, Collective-sphere willpower and waypower, and Lack of willpower and waypower. Each item is rated on a seven-point rating from 1 (strongly disagree) to 7 (strongly agree).
#
# <br>
#
# This dataset was collected as part of research to test if Li and Monroe's (2017) three-factor model fits the data from an adult sample.

# %% [markdown]
# ## Description of the Example
#
# Access this example using the file `example.csv`.
#
# The individual CCHS scale items and additional measures were removed to condense the dataset. The following variables are included in the example:
#
#
# y: Climate Change Hope Scale (CCHS) Total Score
# y1: CCHS Personal Willpower and Waypower Subscale Score
# y2: CCHS Collective Willpower and Waypower Subscale Score
# y3: CCHS Lack of Willpower and Waypower Subscale Score
# x: Gender (1 = Female; 2 = Male; 3 = Non-Binary)
# x1: Age in years
# x2: Hispanic (1 = Yes; 2 = No)
# x3: Race (1 = Black; 2 = Asian; 3 = White; 4 = Native American; 5 = Native Hawaiian or Pacific Islander; 6 = Other)
# x4: Education in years of full time education completed
# x5: Children (1 = Has children; 2 = Does not have children)
# x6: Climate Change Doubt: Personal opinion on whether climate is changing (1 = Yes; 2 = No; 3 = Don't know)

# %% [markdown]
# ## Discipline(s) Represented
#
#
# * Environment
# * Science
# * Civics/Government
# * Economics
# * Social Sciences
# * Health
# * Ethics

# %% [markdown]
# ## Dataset Preview

# %%
#@title Setup Example Data: Climate

# Import library
import pandas as pd

# Read data file: Climate
data = pd.read_csv('https://raw.githubusercontent.com/michellebacareinke/APEX/main/climate/%20example.csv')

# Preview data
data.head()
# Out:
#     y  y1  y2  y3  x  x1  x2  x3  x4  x5  x6
# 0  45  14  20  11  2  24   2   5  16   1   1
# 1  56   3  32  21  1  45   2   3  12   1   2
# 2  39  10  14  15  1  36   2   3  16   1   1
# 3  61  20  32   9  2  41   2   3  16   1   1
# 4  46  12  20  14  1  39   2   3  12   1   3

# %% [markdown]
# ## Exploratory Analyses (untested)
#
# This is a dataset with different types of variables, which opens up the possibility for a wide range of statistical analyses:
#
#
# 1. **Descriptive Statistics**:
# * Calculate the mean, median, standard deviation, and range for CCHS Total Score.
#
# 2. **Distributions**:
# * Examine frequencies for categorical variables such as gender, hispanic, race, education, and children.
# * Plot and examine the distribution of responses for climate change doubt and CCHS Total Score.
# * Investigate the distribution of the CCHS Total Score variable to understand the overall level of hope regarding climate change.
#
# 3. **Correlation Analysis**:
# * Run a Pearson's correlation between age and CCHS total score.
# * Run a Pearson's correlation between years of education and CCHS personal willpower/waypower subscale.
# * Run a Pearson's correlation between years of education and CCHS Total Score.
#
# 5. **T-Tests**:
# * Perform t-test comparing personal willpower/waypower means by having children (yes/no groups).
# * Perform a t-test comparing lack of willpower/waypower means by subsets of age groups (e.g. under 40 vs. 40 and over).
#
#
# 4. **ANOVA**:
# * Perform a one-way ANOVA test comparing CCHS total scores by race groups.
# * Perform a one-way ANOVA comparing lack of willpower/waypower scores by race groups.
# * Perform a one-way ANOVA test comparing collective willpower/waypower scores by subsetted age decade groups.
