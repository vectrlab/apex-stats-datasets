# %% [markdown]
# # APEX STATS Dataset
# Prepared by Michelle Baca Reinke

# %% [markdown]
# ## Source Attribution
#
# Author: Data Copyright &copy; Paul Zak, Claremont Graduate University, All Rights Reserved
#
# Title: Neuraldiversity
#
# Source: [openICPSR](https://www.openicpsr.org/), public access repository supported by the Inter-university Consortium for Political and Social Research (ICPSR)
#
# License: CC BY 4.0 Creative, Commons Attribution 4.0 International License
#
# Changes: Data have been adapted for APEX STATS by Michelle Baca Reinke; data have been condensed in the example version.

# %% [markdown]
# ## Description of the Original Data
#
# These data come from a study that measured nine physiologic factors and collected 16 types of psychological data while participants made decisions in standard tasks from experimental economics measuring risk aversion, intertemporal patience, altruism, cooperation, generosity, trust and trustworthiness.
#
# <br>
#
# The analysis of the original data showed that multiple measures of physiologic stress decrease cooperative behaviors while testosterone consistently increased antisocial behaviors.  Further, cognitive abilities robustly increased patience but decreased cooperation while those more satisfied with their lives were more trustworthy.  Participants scoring high on the personality trait of Imagination were shown to be less altruistic and generous, while those high on Neuroticism were more prosocial.
#
# <br>
#
# Citation: Zak, Paul. Neural Diversity and Decisions: Neural Diversity MasterFile .csv. Ann Arbor, MI: Inter-university Consortium for Political and Social Research [distributor], 2023-11-15. https://doi.org/10.3886/E195143V1-143288

# %% [markdown]
# ## Description of the Example
#
# Access this example using the file `example.csv`.
#
# The following variables are included in the example:
#
# y: Extraversion (Big 5)
# y1: Agreeableness (Big 5)
# y2: Conscientiousness (Big 5)
# y3: Neuroticism (Big 5)
# y4: Openness (Big 5)
# y5: Life Satisfaction
# y6: Positive Affect Schedule
# y7: Negative Affect Schedule
# y8: Dictator Game Score
# y9: Dictator Game Money Sent
# y10: Public Goods Game Profits Score
# y11: Public Goods Game Cooperation Score
# x: Age (in years)
# x1: Sex (biological sex, 1 = male, 2 = female)
# x2: Hispanic (1 = yes, 2 = no)
# x3: Cortisol Levels
# x4: Estradiol Levels
# x5: Progesterone Levels
# x6: Testosterone Levels

# %% [markdown]
# ## Variable Explanations:
#
# Big Five Personality Traits
# * y through y4 are part of the Big Five Personality Traits, a model used in personality psychology for understanding and categorizing trait differences.
#     * Extraversion relates to the degree to which a person is outgoing, social, and energized by interactions with others.
#     * Agreeableness relates to the degree to which a person is kind, cooperative, and considerate.
#     * Conscientiousness relates to the degree to which a person is organized, responsible, and goal-oriented.
#     * Neuroticism relates to the degree to which a person experiences higher emotional instability and are more prone to negative emotions like anxiety and stress.
#     * Openness relates to the degree to which a person is creative, curious, and open to new ideas and experiences.
#
# Subjective Well-Being
# * y5 through y7 Subjective Well-Being relates to an individual's overall evaluation of their life and emotional experiences.
#     * Life Satisfaction refers to an individual's judgment about the overall quality and fulfillment of their life.
#     * Positive Affect involves the frequency and intensity an indivdual experiences positive emotions, such as joy, gratitude, and contentmen.
#     * Negative Affect involves the frequency and intensity an indivdual experiences positive emotions, such as joy, gratitude, and contentment.
#     * Negative  negative emotions, such as sadness, anxiety, and stress.
#
#
# Social Economics
# * y8 and y9 Dictator Game involves one participant (the dictator)who is given a sum of money and has the unilateral decision to share any portion of it with another participant (the recipient). It measures altruism (low scores), fairness (middle scores), and self-interest (high scores) by studying how dictators choose to distribute resources without external influence. Money sent reflects what the dictator chose to share.
# * y10 and y11 Public Goods Game involves participants tasked with deciding how much of their resources to contribute to a shared pool to be distributed among all participants. This measures self-interest (profit score) and collective benefit (cooperation score).
#
# Physiological Measures
# * x4 Cortisol is a steroid hormone often associated with stress response.
# * x5 and x6 Estradiol and progesterone are key hormones involved in the regulation of the biologically female reproductive system. They can modulate the stress response and mood, having anxiolytic (anxiety-reducing) effects. Research suggest that levels can influence social bonding, empathy, and the recognition of social cues, and may enhance social connectedness and communication.
# * x7 Testosterone is a male sex hormone that plays a key role in the development and maintenance of biologically male sexual characteristics and may influence behavior by contributing to traits such as competitiveness, aggression, and risk-taking tendencies.

# %% [markdown]
# ## Discipline(s) Represented
#
# * Biology
# * Economics
# * Social Sciences
# * Health
# * Ethics
# * Political Science
# * Philosophy

# %% [markdown]
# ## Dataset Preview

# %%
#@title Setup Example Data: Neuraldiversity

# Import library
import pandas as pd

# Read data file: Neuraldiversity
data = pd.read_csv('https://raw.githubusercontent.com/michellebacareinke/apex-stats-datasets/patch-1/neuro_div/example.csv')

# Preview data
data.head()
# Out:
#       y    y1    y2    y3    y4   y5   y6   y7   y8   y9       y10  y11   x  \
# 0  4.25  3.75  4.00  3.25  3.75  2.2  5.0  1.3  7.0  3.0  9.000000  0.0  23
# 1  4.75  4.00  5.25  4.00  4.25  4.0  2.2  1.5  5.0  5.0  3.666667  1.0  38
# 2  2.25  4.50  3.75  2.50  3.25  6.4  3.0  1.4  5.0  5.0  3.666667  1.0  18
# 3  4.25  3.75  4.00  3.75  3.50  5.6  2.5  1.5  5.0  5.0  3.666667  1.0  18
# 4  4.50  4.00  3.75  3.75  3.00  2.2  3.5  1.0  6.5  3.5  6.666667  0.0  57
#
#    x1  x2    x3    x4     x5     x6
# 0   2   2  3.17  32.0  0.090   42.5
# 1   1   2  8.28  37.5  0.585   60.0
# 2   2   2  7.06  21.0  0.130   42.5
# 3   2   2  2.92  24.0  0.060   42.5
# 4   1   2  9.44  37.5  0.585  490.0

# %% [markdown]
# ## Exploratory Analyses (untested)
#
# This is a dataset with different types of variables, which opens up the possibility for a wide range of statistical analyses:
#
#
# 1. **Descriptive Statistics**:
# * Calculate the mean, median, standard deviation, and range for age, life satisfaction, positive and negative affect, and the Big Five variables.
#
# 2. **Distributions**:
# * Examine frequencies for categorical variables of sex and hispanic.
# * Plot and examine the distribution of responses for Social Economics variables (y8 through y11).
#
# 3. **Correlation Analysis**:
# * Run a Pearson's correlations between physiological measures (x3 through x6) and the Big Five Personality Traits (y through y4).
# * Run a Pearson's correlations between positive affect (y6) or negative affect (y7) and the Social Economics variables (y8 through y11).
# * Run a Pearson's correlations between physiological measures (x3 through x6) and the Social Economics variables (y8 through y11).
#
# 4. **T-Tests**:
# * Perform t-test comparing males (x1 = 1) and females (x1 = 2) on average life satisfaction (y5) scores.
# * Perform a t-test comparing males (x1 = 1) and females (x1 = 2) on the Social Economics variables (y8 through y11).
#
# 5. **ANOVA**:
# * Split age by 'under 20', '20 to 29', and '30+' and perform a one-way ANOVA to test group differences on the Big Five Personality Traits (y through y4) or Social Economics variables (y8 through y11).
# * Split age by 'under 20', '20 to 29', and '30+' and perform a two-way ANOVA with sex (x1) to test group differences on Social Economics variables (y8 through y11) and their interaction.
