# %% [markdown]
# # APEX STATS Dataset
# Prepared by Michelle Baca Reinke

# %% [markdown]
# ## Source Attribution
#
# Author: Data Copyright &copy; Cary et al. (2023), All Rights Reserved
#
# Title: Observed Instagram Use & Satisfaction With Life
#
# Source: [openICPSR](https://www.openicpsr.org/), public access repository supported by the Inter-university Consortium for Political and Social Research (ICPSR)
#
# License: CC BY 4.0 Creative, Commons Attribution 4.0 International License
#
# Changes: Data have been adapted for APEX STATS by Michelle Baca Reinke; data have been condensed in the example version.

# %% [markdown]
# ## Description of the Original Data
#
# Over 70% of Americans use social media platforms, like Instagram. With this high prevalence, researchers have investigated the relationship between social media use and psychological well-being. Extant research has yielded mixed results, however, as most measures of social media use are self-reported and focus on amount of use. Even when studies account for type of social media use, such as active or passive use, there remains much to be captured. To address this, we asked participants to report their satisfaction with life and then recorded their actual Instagram activity for 10 minutes after posting a “selfie” portrait to their account. Importantly, we coded the observed Instagram activity into the following four clusters of experiences: communications received, communications sent, monitoring self-related content, exploring other-related content. We found that greater life satisfaction was associated with higher frequency of receiving communications and viewing other-related content. Life satisfaction was not associated with frequency of sending communications and self-monitoring. Surprisingly, none of the clusters of Instagram experiences were negatively associated with life satisfaction. Our findings highlight the importance of objective data and moving beyond the active/passive dichotomy of social media use to consider additional experiences.
#
# <br>
#
# In total, 80 participants completed the online survey and had their Instagram use monitored for 10 minutes. The final analytical sample includes 70 participants, 11 individuals were excluded from analysis because they did not follow directions during the experiment (e.g., did not spend the full 10 minutes using the Instagram app).
#
# <br>
#
# The researchers obtained a convenience sample of undergraduate college students who self-selected into the research study completed an online survey assessing satisfaction with life and observational data (coded video) of real-time Instagram app use. Participants completed the 5-item Satisfaction with Life Scale (SWLS). Each item was rated using a 7-point Likert scale (1 = strongly disagree, 7 = strongly agree). The mean of each participant response was calculated, with higher scores indicating greater satisfaction with life (M = 4.75, SD = 1.15).
#
# <br>
#
# Citation: Cary, Kyla, Greer, Kirsten, Maas, Megan, and Meshi, Dar. Observed Instagram Use & Satisfaction With Life. Ann Arbor, MI: Inter-university Consortium for Political and Social Research [distributor], 2023-11-11. https://doi.org/10.3886/E195061V1

# %% [markdown]
# ## Description of the Example
#
# Access this example using the file `example.csv`.
#
# The following variables are included in the example:
#
# y: Self-reported minutes spent on Instagram daily
# y1: Satisfaction with Life; mean score on 5-item scale (1 = strongly disagree, 7 = strongly agree)
# y2: Instagram Communications Received
# y3: Instagram Communications Sent
# y4: Instagram Monitoring Self-Related Content
# y5: Instagram Exploring Other-Related Content
# x: Semester (2 = Fall 2019, 3 = Summer 2020)
# x1: Gender (0 = Male, 1 = Female)
# x3: Age (years)
# x4: Race (1 = American Indian or Alaska Native, 2 = Asian, 3 = Black or African American, 4 = Native Hawaiian or Other Pacific Islander, 5 = White, 6 = Other / Prefer not to answer)
# x5: Ethnicity (1 = Hispanic or Latino, 2 = Not Hispanic or Latino, 3 = Prefer not to answer)

# %% [markdown]
# ## Discipline(s) Represented
#
# * Social Sciences
# * Mental Health

# %% [markdown]
# ## Dataset Preview

# %%
#@title Setup Example Data: IG and Life Satisfaction

# Import library
import pandas as pd

# Read data file: IG and Life Satisfaction
data = pd.read_csv('https://raw.githubusercontent.com/michellebacareinke/apex-stats-datasets/patch-1/soc_media/example.csv')

# Preview data
data.head()
# Out:
#       y   y1    y2    y3    y4     y5  x  x1  x2  x4  x5
# 0   300  4.4   0.0  28.0   4.5   71.5  3   1  18   5   2
# 1   180  4.0   2.0  20.5   3.0  132.0  3   1  20   5   2
# 2     0  4.4   0.0   1.0   3.5   60.0  3   1  22   2   3
# 3  1200  4.8  12.5   6.5  34.0  144.5  3   0  23   2   2
# 4     0  4.4   0.0   7.0   2.0   75.0  3   0  20   2   2

# %% [markdown]
# ## Exploratory Analyses (untested)
#
# This is a dataset with different types of variables, which opens up the possibility for a wide range of statistical analyses:
#
#
# 1. **Descriptive Statistics**:
# * Calculate the mean, median, standard deviation, and range for:
#    * y: Self-reported minutes spent on Instagram daily
#    * y1: Satisfaction with Life Scale
#
# 2. **Distributions**:
# * Examine frequencies for categorical variable:
#     * Semester (x)
# * Plot and examine the distribution of responses for:
#     * y: Self-reported minutes spent on Instagram daily
#     * y1: Satisfaction with Life
#     * y2: Instagram Communications Received
#     * y3: Instagram Communications Sent
#     * y4: Instagram Monitoring Self-Related Content
#     * y5: Instagram Exploring Other-Related Content
#
# 3. **Correlation Analysis**:
# * Run a Pearson's correlation to test the relationship between self-reported minutes spent on Instagram daily (y) and Satisfaction with Life (y1)
# * Run a Pearson's correlation to test the relationship between Instagram Monitoring Self-Related Content (y4) and age (x3).
#
# 4. **Independent Samples *t*-Test**:
# * Perform an independent samples t-test to examine differences in Fall and Summer semesters (x) in self-reported minutes spent on Instagram daily (y).
